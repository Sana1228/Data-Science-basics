# %% [markdown]
# # Assignment 25

# %% [markdown]
# #### Date : 02/03/2023

# %% [markdown]
# #### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# #### Answer:
# Matplotlib is a plotting library for Python that provides a wide range of visualization tools to create 2D and 3D plots. It is used for visualizing data in a variety of formats, such as line plots, scatter plots, histograms, bar charts, and more.
#
# Matplotlib is used in data analysis, scientific research, and engineering to create high-quality, professional-looking plots and visualizations that help to better understand the data.
#
# Pyplot module is a sub-library of Matplotlib that provides a collection of functions to create a variety of basic plots like line plot, scatter plot, bar plot, histogram and pie chart.
#
# Here are five plots that can be plotted using the Pyplot module of Matplotlib:
#
# 1. Line Plot
# 2. Scatter Plot
# 3. Bar Chart
# 4. Histogram
# 5. Pie Chart
#
# These plots can be created using various functions provided by the Pyplot module of Matplotlib.

# %% [markdown]
# #### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# #### Answer:

# %%
import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
import matplotlib.pyplot as plt

# Plot the scatter plot
plt.scatter(x, y)

# Add title, xlabel, and ylabel
plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')

# Display the plot
plt.show()

# %% [markdown]
# #### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# #### Answer:
# The subplot() function is used to create multiple plots within the same figure. This is useful when you want to compare different sets of data or visualize multiple related plots in a single figure.
#
# The subplot() function takes three arguments: nrows, ncols, and index. The nrows and ncols parameters specify the number of rows and columns of plots in the figure, while the index parameter specifies the position of the current plot within the grid of plots.
#
# Here's an example of using the subplot() function to create four line plots:

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title('Line 1')

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title('Line 2')

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title('Line 3')

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title('Line 4')

plt.show()

# %% [markdown]
# #### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# #### Answer:

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Creating a bar plot
plt.bar(company, profit)
plt.title('Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# Creating a horizontal bar plot
plt.barh(company, profit)
plt.title('Company Profits')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# #### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# #### Answer:

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

# Creating the box plot
plt.boxplot(data)
plt.title('Box Plot Example')
plt.xticks([1, 2], ['Box 1', 'Box 2'])
plt.xlabel('Box')
plt.ylabel('Value')
plt.show()
